# %%
from _001_main import df_csv
import pandas as pd
import numpy as np
df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# 1_Задача: Проверка числа на простоту (is_prime) с валидацией типов.
# Условия:
# Реализовать функцию is_prime(n).
# Аргумент n может быть не только int, но и float, и str (например, '2017', '12709189.00').
# Алгоритм должен быть эффективным (подходить для больших чисел, как 18375703).
# Критерии простого числа: строго целое, >1, имеет ровно 2 делителя.
# Ожидаемое поведение:
# is_prime(2.0) -> True
# is_prime('2017') -> True
# is_prime(1) -> False
# is_prime('abc') -> False


# def is_prime(n):
#     try:
#         n = int(float(n))
#     except (TypeError, ValueError):
#         return False
    
#     if n < 2:
#         return False
    
#     for i in range(2, int(n ** 0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
#     pass



def is_prime(n):
    try:
        n = int(float(n))
    except (TypeError, ValueError):
        return False
    pass
    
    if n < 2:
        return False
    
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
        else:
            return True



print(is_prime(2.0))
print(is_prime('2017'))
print(is_prime('12709189.00'))
print(is_prime(1))
print(is_prime('abc'))
# Out:
# True
# True
# False
# False
# False

# %%
# Условие: На вход функции matrix подаётся число N. Функция возвращает матрицу-спираль, закрученную против часовой стрелки, размера NxN. Пример для 3х3:



n = 3

def matrix (n):
    mat = [[0] * n for _ in range(n)]

    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
    current_dirrection = 0

    y, x = 0, 0

    for num in range(1, n * n + 1):
        mat[y][x] = num

        dy, dx = directions[current_dirrection]
        new_y, new_x = y + dy, x + dx

        if not (0 <= new_y < n and 0 <= new_x < n and mat[new_y][new_x] == 0):
            current_dirrection = (current_dirrection + 1) % 4
            dy, dx = directions[current_dirrection]
            new_y, new_x = y + dy, x + dx
        y, x = new_y, new_x
    return mat






def matrix (n):
    mat = [[0] * n for _ in range(n)]
    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
    current_direction = 0
    x, y = 0, 0

    for num in range(1, n * n +1):
        mat[y][x] = num
        dy, dx = directions[current_direction]
        new_y, new_x = y + dy, x + dx

        if not (0 <= new_y < n and 0 <= new_x < n and mat[new_y][new_x] == 0):
            current_direction = (current_direction + 1) % 4
            dy, dx = directions[current_direction]
            new_y, new_x = y + dy, x + dx
        
        y, x = new_y, new_x
    return mat








def matrix (n):
    mat = [[0] * n for _ in range(n)]
    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
    current_directions = 0
    y, x = 0, 0

    for num in range(1, n * n + 1):
        mat[y][x] = num
        dy, dx =  directions[current_directions]
        new_y, new_x = y + dy, x + dx

        if not ():
            current_directions = (current_directions + 1) % 4
            dy, dx =  directions[current_directions]    
            new_y, new_x = y + dy, x + dx 
        y, x = new_y, new_x

    return mat  






def rle (string):
    if not string:
        return ""
    
    result = []
    count = 1
    prev_char = string[0]

    for i in range(1, len(string)):
        curr_char = string[i]
        if curr_char == prev_char:
            count += 1
        else:
            result.append(f"{count}{prev_char}")
            prev_char = curr_char
            count = 1
        result.append(f"{count}{prev_char}")
    return "".join(result)


print(rle('wwwww`wbwwwwwwbbbwwwwwwwwwwb'))
print(rle('aaabb'))
print(rle('a'))








def rle (string):
    if not string:
        return ""
    
    result = []
    count += 1
    prev_char = string[0]

    for i in range(1, len(string)):
        curr_char = string[i]
        if curr_char == prev_char:
            count += 1

        else:
            result.append(f"{count}{prev_char}")
            prev_char = curr_char
            count = 1
        result.append(f"{count}{prev_char}")
    return "".join(result)






def rle (string):
    if not string:
        return ""
    result = []
    prev_char = string[0]
    count = 1

    for i in range(1, len(string)):
        curr_char = string[i]
        if curr_char == prev_char:
            count += 1

        else:
            result.append(f"{count}{prev_char}")
            prev_char = curr_char
            count = 1
        result.append(f"{count}{prev_char}")
    return "".join(result)
        


import math
def formula (x, y, z):
    num1 = 3 * (x ** 2)
    num2 = 4 * math.exp(x * y)
    num3 = math.sqrt(3) * math.log(z) * x * (y ** 4) * math.sin(y)
    znam = math.pi * math.log10(z)

    result = (num1 - num2 + num3) / znam
    return result


def matrix (n):
    mat = [[0] * n for _ in range(n)]
    
    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
    current_directions = 0
    y, x = 0, 0

    for num in range(1, n * n + 1):
        mat[y][x] = num
        dy, dx = directions[current_directions]
        new_y, new_x = y + dy, x + dx

        if not (0 <= new_y < n and 0 <= new_x < n and mat[new_y][new_x] == 0):
            current_directions = (current_directions + 1) % 4
            dy, dx = directions[current_directions]
            new_y, new_x = y + dy, x + dx
        y, x = new_y, new_x
    return mat


def rle(string):
    if not string:
        return ""
    
    result = []
    prev_char = string[0]
    count = 1

    for i in range(2, len(string)):
        curr_char = string[i]
        if curr_char == prev_char:
            count += 1
        else:
            result.append(f"{count}{prev_char}")
            prev_char = curr_char
            count = 1
        result.append(f"{count}{prev_char}")
    return "".join(result)
