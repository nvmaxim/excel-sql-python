# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
ts = [(1, 5), (1, 7), (2, 8)]

elements = list(zip(*ts))

sums = tuple((sum(item)) for item in elements)

averages = tuple((sum(item) / len(item)) for item in elements) 
print(elements)
print(sums)
print(averages)
# Out:
# [(1, 1, 2), (5, 7, 8)]
# (4, 20)
# (1.3333333333333333, 6.666666666666667)
