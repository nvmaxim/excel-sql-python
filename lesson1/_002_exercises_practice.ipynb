# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# Вопрос:
# Дана строка. Нужно создать копию, где символы исходной строки с нечётными индексами (1,3,5,…) переставлены в обратном порядке, а символы с чётными индексами остаются на местах. Вывести результат. ввод 0123456789 должен быть такой результат 0927456381

import sys
import io

sys.setrecursionlimit(2000)


def get_algo_logic(string: str) -> str:
    odd = ""
    i = 0
    for char in string:
        if i % 2 == 1:
            odd += char
        i += 1
    sorted_result = ""
    k = 0
    len_odd = 0
    for _ in odd:
        odd += 1

    for char in string:
        if i % 2 == 0:
            sorted_result += char

    pass


def solve():
    pass


def main():
    IS_LOCAL_TEST = True
    if IS_LOCAL_TEST:
        raw_data = "0123456789"
        input_stream = io.StringIO(raw_data).read()
    else:
        input_stream = sys.stdin.read()
    solve(input_stream)


if __name__ == "__main__":
    main()
# Out:
#   manager department  sales  experience period   Bonus
# 4  Сергей          Б  25000           4     Q1  2500.0
# 1   Мария          Б  22000           5     Q1  2200.0
# 6   Мария          Б  19000           5     Q2  1900.0
# 5    Иван          А  18000           2     Q2  1800.0
# 2    Петр          А  17000           3     Q1  1700.0
# 8   Ольга          А  16000           2     Q2  1600.0
# 0    Иван          А  15000           2     Q1  1500.0

# %%
ggl = 10 ** 100
ggl_len = len(str(ggl))

min_ = math.floor(math.log2(ggl))
max_ = math.ceil(math.log2(ggl))
print(ggl_len)
