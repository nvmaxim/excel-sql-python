# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
nucleotides = ['A', 'T', 'G', 'C']

def get_algo(sequence):
    sub_sequence = []
    for element in sequence:
        new_subs= [[]]
        for subseq in sub_sequence:
            new_subs.append(subseq + [element])
        sub_sequence.extend(new_subs)
    return sub_sequence
# Out:
# the - 4
# a - 4
# its - 4
# is - 4
# in - 5
# language - 5
# programming - 5
# as - 7
# and - 8
# python - 11
# ...
