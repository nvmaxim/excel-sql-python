# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# УПРАЖНЕНИЕ 1: "Анализ эффективности менеджеров (python)
# В каком отделе (А или Б) менеджеры в среднем приносят больше выручки?
import pandas as pd


df_result = df[df["department"].isin("А", "Б")].groupby("department").agg({"revenue", "mean"}).rename(columns={"revenue": "avg_revenue"}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       1 # УПРАЖНЕНИЕ 1: "Анализ эффективности менеджеров (python)
#       2 # В каком отделе (А или Б) менеджеры в среднем приносят больше выручки?
#       3 import pandas as pd
# ----> 6 df_result = df[df["department"].isin("А", "Б")].groupby("department").agg({"revenue", "mean"}).rename(columns={"revenue": "avg_revenue"}).reset_index()
#
# TypeError: Series.isin() takes 2 positional arguments but 3 were given
