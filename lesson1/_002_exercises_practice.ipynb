# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# УПРАЖНЕНИЕ 3: "Консолидация данных (python)
# Объедините данные за Q1 и Q2, сгруппируйте по менеджерам и посчитайте общую выручку для каждого менеджера за оба периода.

import pandas as pd

period_q1 = df[df["period"] == "Q1"][["manager", "revenue"]].reset_index(drop=True)

period_q2 = df[df["period"] == "Q2"][["manager", "revenue"]].reset_index(drop=True)

combined = pd.concat((period_q1, period_q2))

result = combined.groupby("manager").agg(total_revenue=("revenue", "sum")).sort_values("total_revenue", ascending=False).reset_index()
print(result)
# Out:
#   manager  total_revenue
# 0   Мария          41000
# 1    Иван          33000
# 2    Анна          26000
# 3  Сергей          25000
# 4    Петр          17000
# 5   Ольга          16000
