# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
import cmath
import math
import sys
x = math.pi / 4
left = cmath.exp(1j * x)
right = math.cos(x) + 1j * math.sin(x)
print(left == right)

xs = [1, 10, 13, 42, 98, 99, 137, 512, 1001, 1024, 2048, 4096, 8192, 10001]

for i, x in enumerate(xs):
    if i % 2 == 0 and x % 2 == 1:
        formula = math.cos(x) + 1j * math.sin(x)
        print(f"cos{x} + mnim * sin{x} = {formula}", file=sys.stderr)
    elif x % 2 == 0:
        print(bin(x))
    else:
        print(oct(x))
# Out:
# True
# 0b1010
# 0b101010
# 0b1100010
# 0o143
# 0b1000000000
# 0b10000000000
# 0b100000000000
# 0b1000000000000
# 0b10000000000000
# 0o23421
# cos1 + mnim * sin1 = (0.5403023058681398+0.8414709848078965j)
# cos13 + mnim * sin13 = (0.9074467814501962+0.4201670368266409j)
# cos137 + mnim * sin137 = (0.33416538263076073-0.9425144545582509j)
# cos1001 + mnim * sin1001 = (-0.3919404295971039+0.9199905975863218j)
