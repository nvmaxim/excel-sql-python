# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
literature01 = [
    'אשפה ואוסף דינמי באופן מוקלד פייתון!',
    ' מונחה ,)במיוחד (פרוצדורלי( מובנה תכנות כולל ,מרובות תכנות בפרדיגמות תומך הוא ופונקציונלי עצמים.',
    ' הסטנדרטית הספרייה בשל " כלולות סוללות "כשפה קרובות לעתים מתואר זה שלה המקיפה?',
]

literature02 = [
    'است شده جمع زباله و شده تایپ پویا صورت به پایتون!',
    'این پشتیبانی از پارادایم های برنامه نویسی متعدد, از جمله ساختار (به خصوص رویه), برنامه نویسی شی گرا و کاربردی.',
    'این است که اغلب به عنوان یک "باتری شامل" زبان با توجه به کتابخانه استاندارد جامع خود توصیف?',
]

literature03 = [
    'uqydfqixa;sd jsdviwwbdhu qwertyuiop',
    'asdfgh DDFGHJ ghjl',
    'zxc cvb vbn cvb bn n,',
    'n,.n l;l QWESs WERTYU123',
]

def get_algo(literature):
    combined_text = "".join(literature)
    unique = sorted(set(combined_text))
    power = len(unique)
    alphabet = "".join(unique)
    return f" {alphabet} - {po}"
# Out:
# [1, 2, 3, 5, 8, 13]
# [34, 4, 6, 7, 9, 10, 11, 12, 21, 55, 89]
# [89, 34, 21, 55]
# [4, 6, 7, 9, 10, 11, 12]
# False
# 9
