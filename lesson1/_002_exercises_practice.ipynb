# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# УПРАЖНЕНИЕ 2: "Классификация клиентов (python)
# Классифицируйте клиентов по уровню выручки на VIP, Standard и Basic. Найдите всех VIP-клиентов и отсортируйте их по убыванию выручки.

import numpy as np

df["category"] = np.where(df["revenue"] >= 20000, "VIP", np.where(df["revenue"] >= 10000, "Standart", "Basic"))

result = df[df["category"] == "VIP"].sort_values("revenue", ascending=False)

print(result)
# Out:
#   manager department  revenue  experience period category
# 4  Сергей          Б    25000           4     Q1      VIP
# 1   Мария          Б    22000           5     Q1      VIP

# %%
a = "maabccdee"
b = "ddeffggaaz"
# Результат: "abcdefgz"

combined = a + b
unique = ""
for char in combined:
    if char not in unique:
        unique += char

sorted_result = ""

min_char = unique[0]
for char in unique:
    if char < min_char:

print()
# Out:
# mabcdefgz
